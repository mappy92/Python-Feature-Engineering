# %%
import datetime
import numpy as np
import pandas as pd

# %%
# let's create a toy dataframe with some date variables

rng_hr = pd.date_range('2019-03-05', periods=20, freq='H')
rng_month = pd.date_range('2019-03-05', periods=20, freq='M')

df = pd.DataFrame({'date1': rng_hr, 'date2': rng_month}) 
df.head()
# Out:
# C:\Users\manpr\AppData\Local\Temp\ipykernel_25404\506613659.py:3: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   rng_hr = pd.date_range('2019-03-05', periods=20, freq='H')
# C:\Users\manpr\AppData\Local\Temp\ipykernel_25404\506613659.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   rng_month = pd.date_range('2019-03-05', periods=20, freq='M')
#                 date1      date2
# 0 2019-03-05 00:00:00 2019-03-31
# 1 2019-03-05 01:00:00 2019-04-30
# 2 2019-03-05 02:00:00 2019-05-31
# 3 2019-03-05 03:00:00 2019-06-30
# 4 2019-03-05 04:00:00 2019-07-31

# %%
# let's capture the difference in days between the 2 variables

df['elapsed_days'] = (df['date2'] - df['date1']).dt.days

df.head()
# Out:
#                 date1      date2  elapsed_days
# 0 2019-03-05 00:00:00 2019-03-31            26
# 1 2019-03-05 01:00:00 2019-04-30            55
# 2 2019-03-05 02:00:00 2019-05-31            86
# 3 2019-03-05 03:00:00 2019-06-30           116
# 4 2019-03-05 04:00:00 2019-07-31           147

# %%
# let's capture the difference in months between the 2 variables

#df['months_passed'] = ((df['date2'] - df['date1']) / np.timedelta64(1, 'M'))
#df['months_passed'] = np.round(df['months_passed'],0)

df['months_passed'] = (
    (df['date2'].dt.year - df['date1'].dt.year) * 12 +
    (df['date2'].dt.month - df['date1'].dt.month)
)

df['months_passed'] = df['months_passed'].astype(int)

df.head()
# Out:
#                 date1      date2  elapsed_days  months_passed
# 0 2019-03-05 00:00:00 2019-03-31            26              0
# 1 2019-03-05 01:00:00 2019-04-30            55              1
# 2 2019-03-05 02:00:00 2019-05-31            86              2
# 3 2019-03-05 03:00:00 2019-06-30           116              3
# 4 2019-03-05 04:00:00 2019-07-31           147              4

# %%
# calculate difference in seconds and minutes

df['diff_seconds'] = (df['date2'] - df['date1'])/np.timedelta64(1,'s')
df['diff_minutes'] = (df['date2'] - df['date1'])/np.timedelta64(1,'m')

df.head()
# Out:
#                 date1      date2  elapsed_days  months_passed  diff_seconds  \
# 0 2019-03-05 00:00:00 2019-03-31            26              0     2246400.0
# 1 2019-03-05 01:00:00 2019-04-30            55              1     4834800.0
# 2 2019-03-05 02:00:00 2019-05-31            86              2     7509600.0
# 3 2019-03-05 03:00:00 2019-06-30           116              3    10098000.0
# 4 2019-03-05 04:00:00 2019-07-31           147              4    12772800.0
#
#    diff_minutes
# 0       37440.0
# 1       80580.0
# 2      125160.0
# 3      168300.0
# 4      212880.0

# %%
# calculate difference to today

df['to_today'] = (datetime.datetime.today() - df['date1'])

df.head()
# Out:
#                 date1      date2  elapsed_days  months_passed  diff_seconds  \
# 0 2019-03-05 00:00:00 2019-03-31            26              0     2246400.0
# 1 2019-03-05 01:00:00 2019-04-30            55              1     4834800.0
# 2 2019-03-05 02:00:00 2019-05-31            86              2     7509600.0
# 3 2019-03-05 03:00:00 2019-06-30           116              3    10098000.0
# 4 2019-03-05 04:00:00 2019-07-31           147              4    12772800.0
#
#    diff_minutes                  to_today
# 0       37440.0 2429 days 20:39:27.150382
# 1       80580.0 2429 days 19:39:27.150382
# 2      125160.0 2429 days 18:39:27.150382
# 3      168300.0 2429 days 17:39:27.150382
# 4      212880.0 2429 days 16:39:27.150382
